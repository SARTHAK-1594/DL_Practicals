# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,\
	Embedding, Lambda
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import re

# %%
data = """We are about to study the idea of a computational process.
Computational processes are abstract beings that inhabit computers.
As they evolve, processes manipulate other abstract things called data.
The evolution of a process is directed by a pattern of rules
called a program. People create programs to direct processes. In effect,
we conjure the spirits of the computer with our spells."""

# %%
# for importing data from txt file
# with open("data.txt", "r", encoding="utf-8") as file:
#     data = file.read()

# %%
sentences = data.split(".")

# %%
sentences
# Out:
# ['We are about to study the idea of a computational process',
#  '\nComputational processes are abstract beings that inhabit computers',
#  '\nAs they evolve, processes manipulate other abstract things called data',
#  '\nThe evolution of a process is directed by a pattern of rules\ncalled a program',
#  ' People create programs to direct processes',
#  ' In effect,\nwe conjure the spirits of the computer with our spells',
#  '']

# %%
#Clean Data
clean_sentences = []
for sentence in sentences:
    # skip empty string
    if sentence == "":
        continue;
    # remove special characters
    sentence = re.sub('[^A-Za-z0-9]+', ' ', sentence)
    # remove 1 letter words
    sentence = re.sub(r'(?:^| )\w(?:$| )', ' ', sentence).strip()
    # lower all characters
    sentence = sentence.lower()
    clean_sentences.append(sentence)

# %%
clean_sentences
# Out:
# ['we are about to study the idea of computational process',
#  'computational processes are abstract beings that inhabit computers',
#  'as they evolve processes manipulate other abstract things called data',
#  'the evolution of process is directed by pattern of rules called program',
#  'people create programs to direct processes',
#  'in effect we conjure the spirits of the computer with our spells']

# %%
# Define the corpus
corpus = clean_sentences

# %%
# Convert the corpus to a sequence of integers
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
sequences = tokenizer.texts_to_sequences(corpus)
print("After converting our words in the corpus \
into vector of integers:")
print(sequences)
# Out:
# After converting our words in the corpus into vector of integers:
# [[4, 5, 11, 6, 12, 1, 13, 2, 7, 8], [7, 3, 5, 9, 14, 15, 16, 17], [18, 19, 20, 3, 21, 22, 9, 23, 10, 24], [1, 25, 2, 8, 26, 27, 28, 29, 2, 30, 10, 31], [32, 33, 34, 6, 35, 3], [36, 37, 4, 38, 1, 39, 2, 1, 40, 41, 42, 43]]

# %%
# creating dictionary for word to index and index to word
index_to_word_map = {}
word_to_index_map = {}
for index_1, sequence in enumerate(sequences):
    print(sequence)
    words_in_sentence = clean_sentences[index_1].split()
    print(words_in_sentence)
    for index_2, value in enumerate(sequence):
        index_to_word_map[value] = words_in_sentence[index_2]
        word_to_index_map[words_in_sentence[index_2]] = value
# Out:
# [4, 5, 11, 6, 12, 1, 13, 2, 7, 8]
# ['we', 'are', 'about', 'to', 'study', 'the', 'idea', 'of', 'computational', 'process']
# [7, 3, 5, 9, 14, 15, 16, 17]
# ['computational', 'processes', 'are', 'abstract', 'beings', 'that', 'inhabit', 'computers']
# [18, 19, 20, 3, 21, 22, 9, 23, 10, 24]
# ['as', 'they', 'evolve', 'processes', 'manipulate', 'other', 'abstract', 'things', 'called', 'data']
# [1, 25, 2, 8, 26, 27, 28, 29, 2, 30, 10, 31]
# ['the', 'evolution', 'of', 'process', 'is', 'directed', 'by', 'pattern', 'of', 'rules', 'called', 'program']
# [32, 33, 34, 6, 35, 3]
# ['people', 'create', 'programs', 'to', 'direct', 'processes']
# [36, 37, 4, 38, 1, 39, 2, 1, 40, 41, 42, 43]
# ['in', 'effect', 'we', 'conjure', 'the', 'spirits', 'of', 'the', 'computer', 'with', 'our', 'spells']

# %%
print(index_to_word_map)
print("\n")
print(word_to_index_map)
# Out:
# {4: 'we', 5: 'are', 11: 'about', 6: 'to', 12: 'study', 1: 'the', 13: 'idea', 2: 'of', 7: 'computational', 8: 'process', 3: 'processes', 9: 'abstract', 14: 'beings', 15: 'that', 16: 'inhabit', 17: 'computers', 18: 'as', 19: 'they', 20: 'evolve', 21: 'manipulate', 22: 'other', 23: 'things', 10: 'called', 24: 'data', 25: 'evolution', 26: 'is', 27: 'directed', 28: 'by', 29: 'pattern', 30: 'rules', 31: 'program', 32: 'people', 33: 'create', 34: 'programs', 35: 'direct', 36: 'in', 37: 'effect', 38: 'conjure', 39: 'spirits', 40: 'computer', 41: 'with', 42: 'our', 43: 'spells'}
#
#
# {'we': 4, 'are': 5, 'about': 11, 'to': 6, 'study': 12, 'the': 1, 'idea': 13, 'of': 2, 'computational': 7, 'process': 8, 'processes': 3, 'abstract': 9, 'beings': 14, 'that': 15, 'inhabit': 16, 'computers': 17, 'as': 18, 'they': 19, 'evolve': 20, 'manipulate': 21, 'other': 22, 'things': 23, 'called': 10, 'data': 24, 'evolution': 25, 'is': 26, 'directed': 27, 'by': 28, 'pattern': 29, 'rules': 30, 'program': 31, 'people': 32, 'create': 33, 'programs': 34, 'direct': 35, 'in': 36, 'effect': 37, 'conjure': 38, 'spirits': 39, 'computer': 40, 'with': 41, 'our': 42, 'spells': 43}

# %%
# Define the parameters
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 10
window_size = 2

# Generate the context-target pairs
contexts = []
targets = []
for sequence in sequences:
	for i in range(window_size, len(sequence) - window_size):
		context = sequence[i - window_size:i] + sequence[i + 1:i + window_size + 1]
		target = sequence[i]
		contexts.append(context)
		targets.append(target)

# %%
# sample of training data
for i in range(5):
    words = []
    target = index_to_word_map.get(targets[i])
    for j in contexts[i]:
        words.append(index_to_word_map.get(j))
    print(words, "=>", target)
# Out:
# ['we', 'are', 'to', 'study'] => about
# ['are', 'about', 'study', 'the'] => to
# ['about', 'to', 'the', 'idea'] => study
# ['to', 'study', 'idea', 'of'] => the
# ['study', 'the', 'of', 'computational'] => idea

# %%
# Convert the contexts and targets to numpy arrays
X = np.array(contexts)
Y = np.array(targets)

# %%
# Define the CBOW model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_size, input_length=2 * window_size))
model.add(Lambda(lambda x: tf.reduce_mean(x, axis=1)))
model.add(Dense(256, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(units=vocab_size, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, Y, epochs=200, verbose=1)
# Out:
# C:\Users\sspag\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\sspag\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 27s 486ms/step - accuracy: 0.0294 - loss: 3.7849
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2353 - loss: 3.7761
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1765 - loss: 3.7705
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.1765 - loss: 3.7635
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.1471 - loss: 3.7552
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1765 - loss: 3.7457
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1765 - loss: 3.7337
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1765 - loss: 3.7196
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1471 - loss: 3.7012
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1765 - loss: 3.6806
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2059 - loss: 3.6555
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2059 - loss: 3.6250
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2059 - loss: 3.5907
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2059 - loss: 3.5519
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.2059 - loss: 3.5094
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2059 - loss: 3.4674
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2059 - loss: 3.4174
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2059 - loss: 3.3689
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2059 - loss: 3.3151
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2059 - loss: 3.2660
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.1471 - loss: 3.2199
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1176 - loss: 3.1787
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.1176 - loss: 3.1437
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.1765 - loss: 3.1086
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.2059 - loss: 3.0761
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.2059 - loss: 3.0470
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.1471 - loss: 3.0220
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0882 - loss: 2.9929
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0882 - loss: 2.9649
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.0882 - loss: 2.9336
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.0882 - loss: 2.9011
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1176 - loss: 2.8679
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1176 - loss: 2.8388
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1176 - loss: 2.8057
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.1176 - loss: 2.7710
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.1471 - loss: 2.7266
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.1765 - loss: 2.6842
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.2353 - loss: 2.6376
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2941 - loss: 2.5960
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3235 - loss: 2.5542
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3529 - loss: 2.5180
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2941 - loss: 2.4824
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2941 - loss: 2.4480
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.2647 - loss: 2.4210
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1765 - loss: 2.4000
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.1765 - loss: 2.3736
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2353 - loss: 2.3322
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.2941 - loss: 2.2871
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3235 - loss: 2.2469
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3529 - loss: 2.2077
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3235 - loss: 2.1689
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2941 - loss: 2.1304
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2941 - loss: 2.0951
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3235 - loss: 2.0610
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3529 - loss: 2.0275
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3824 - loss: 1.9928
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4412 - loss: 1.9497
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4706 - loss: 1.9032
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4412 - loss: 1.8673
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4412 - loss: 1.8392
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4118 - loss: 1.8071
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4412 - loss: 1.7773
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4706 - loss: 1.7430
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4706 - loss: 1.7025
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4706 - loss: 1.6587
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4706 - loss: 1.6184
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4412 - loss: 1.5819
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4706 - loss: 1.5451
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4706 - loss: 1.5133
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5588 - loss: 1.4741
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 1.4363
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6176 - loss: 1.3998
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6176 - loss: 1.3629
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6765 - loss: 1.3344
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6471 - loss: 1.3036
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6471 - loss: 1.2772
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6176 - loss: 1.2518
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6765 - loss: 1.2319
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6765 - loss: 1.2075
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6765 - loss: 1.1803
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6471 - loss: 1.1541
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6471 - loss: 1.1319
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6176 - loss: 1.1112
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6176 - loss: 1.0900
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6765 - loss: 1.0564
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7353 - loss: 1.0274
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7059 - loss: 1.0069
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6765 - loss: 0.9895
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6765 - loss: 0.9674
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6471 - loss: 0.9453
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6471 - loss: 0.9218
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6471 - loss: 0.9121
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6471 - loss: 0.9018
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6765 - loss: 0.8846
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7353 - loss: 0.8550
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7353 - loss: 0.8244
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7353 - loss: 0.8003
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7647 - loss: 0.7677
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7941 - loss: 0.7334
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8235 - loss: 0.7066
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8529 - loss: 0.6772
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8529 - loss: 0.6669
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8235 - loss: 0.6586
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.8235 - loss: 0.6471
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8529 - loss: 0.6401
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8824 - loss: 0.6345
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8529 - loss: 0.6312
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7941 - loss: 0.6146
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8529 - loss: 0.5901
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9118 - loss: 0.5699
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8824 - loss: 0.5528
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9118 - loss: 0.5318
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9412 - loss: 0.5091
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9118 - loss: 0.4882
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8824 - loss: 0.4863
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8824 - loss: 0.4841
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9118 - loss: 0.4832
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9118 - loss: 0.4799
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9118 - loss: 0.4699
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9118 - loss: 0.4504
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9118 - loss: 0.4304
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9118 - loss: 0.4125
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9706 - loss: 0.3980
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9412 - loss: 0.3814
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9412 - loss: 0.3656
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9412 - loss: 0.3643
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9412 - loss: 0.3558
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9412 - loss: 0.3483
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.9706 - loss: 0.3412
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9706 - loss: 0.3295
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.3188
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9412 - loss: 0.3177
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.9412 - loss: 0.3288
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9412 - loss: 0.3419
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9412 - loss: 0.3525
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9412 - loss: 0.3547
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9412 - loss: 0.3335
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - accuracy: 0.9412 - loss: 0.3005
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.9706 - loss: 0.2769
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.9706 - loss: 0.2537
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.2332
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9706 - loss: 0.2320
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9706 - loss: 0.2280
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.9706 - loss: 0.2260
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9706 - loss: 0.2235
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9706 - loss: 0.2179
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9706 - loss: 0.2104
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9706 - loss: 0.2043
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9706 - loss: 0.2004
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.1979
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.1990
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9706 - loss: 0.2028
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9706 - loss: 0.2030
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.9706 - loss: 0.2016
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9706 - loss: 0.1993
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9706 - loss: 0.1955
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9706 - loss: 0.1906
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9706 - loss: 0.1838
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9706 - loss: 0.1777
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9706 - loss: 0.1688
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9706 - loss: 0.1548
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.1444
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9706 - loss: 0.1473
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9706 - loss: 0.1603
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9706 - loss: 0.1513
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9706 - loss: 0.1411
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9706 - loss: 0.1335
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.1290
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.1260
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.1229
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.1197
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 1.0000 - loss: 0.1169
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.1138
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.1112
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.1096
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.1088
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.1078
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.1056
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 1.0000 - loss: 0.1067
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9706 - loss: 0.1146
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9706 - loss: 0.1242
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9706 - loss: 0.1324
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9706 - loss: 0.1374
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9706 - loss: 0.1379
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9706 - loss: 0.1344
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9706 - loss: 0.1274
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9706 - loss: 0.1183
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9706 - loss: 0.1087
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9706 - loss: 0.0999
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.9706 - loss: 0.0925
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 1.0000 - loss: 0.0870
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 1.0000 - loss: 0.0814
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0771
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 0.0743
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0733
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0716
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0702
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0696
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0696
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0701

# %%
# Get the word embeddings
embeddings = model.get_weights()[0]

# Perform PCA to reduce the dimensionality of the embeddings
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(embeddings)

# %%
# Visualize the embeddings
plt.figure(figsize=(7, 7))
for i, word in enumerate(tokenizer.word_index.keys()):
    x, y = reduced_embeddings[i]
    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(5, 2),
                 textcoords='offset points',
                 ha='right', va='bottom')
plt.show()

# %%
# test model
test_sentenses = [
    "we are to study",
    "create programs direct processes",
    "spirits process study program",
    "idea study people create"
]

# %%
for test_sentense in test_sentenses:
    test_words = test_sentense.split(" ")
    print("Words: ", test_words)
    x_test = []
    for i in test_words:
        x_test.append(word_to_index_map.get(i))
    x_test = np.array([x_test])
    print("Indexs: ", x_test)
    test_predictions = model.predict(x_test)
    y_pred = np.argmax(test_predictions[0])
    print("Predictons: ",test_words, " => ", index_to_word_map.get(y_pred))
    print("\n")
# Out:
# Words:  ['we', 'are', 'to', 'study']
# Indexs:  [[ 4  5  6 12]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# Predictons:  ['we', 'are', 'to', 'study']  =>  about
#
#
# Words:  ['create', 'programs', 'direct', 'processes']
# Indexs:  [[33 34 35  3]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# Predictons:  ['create', 'programs', 'direct', 'processes']  =>  to
#
#
# Words:  ['spirits', 'process', 'study', 'program']
# Indexs:  [[39  8 12 31]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# Predictons:  ['spirits', 'process', 'study', 'program']  =>  the
#
#
# Words:  ['idea', 'study', 'people', 'create']
# Indexs:  [[13 12 32 33]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Predictons:  ['idea', 'study', 'people', 'create']  =>  programs
